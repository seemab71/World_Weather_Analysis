# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        print("OK")
        print(city.title())
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        print("OK")
        print(city.title())
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        #print(city_lat)
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # cw = city_weather["weather"]
        # dc = cw[0]
        city_weather_description = city_weather["weather"][0]["description"]
        # print(city_weather_description)  
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# OK
# Ribeira Grande
# OK
# Ribeira Grande
# City not found. Skipping...
# Processing Record 2 of Set 1 | songjianghe
# OK
# Songjianghe
# OK
# Songjianghe
# City not found. Skipping...
# Processing Record 3 of Set 1 | lichinga
# OK
# Lichinga
# OK
# Lichinga
# City not found. Skipping...
# Processing Record 4 of Set 1 | ushuaia
# OK
# Ushuaia
# OK
# Ushuaia
# City not found. Skipping...
# Processing Record 5 of Set 1 | tasiilaq
# OK
# Tasiilaq
# OK
# Tasiilaq
# City not found. Skipping...
# Processing Record 6 of Set 1 | yellowknife
# OK
# Yellowknife
# OK
# Yellowknife
# City not found. Skipping...
# Processing Record 7 of Set 1 | taolanaro
# OK
# Taolanaro
# OK
# Taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | kapaa
# OK
# Kapaa
# OK
# Kapaa
# City not found. Skipping...
# Processing Record 9 of Set 1 | tuatapere
# OK
# Tuatapere
# OK
# Tuatapere
# City not found. Skipping...
# Processing Record 10 of Set 1 | maine-soroa
# OK
# Maine-Soroa
# OK
# Maine-Soroa
# City not found. Skipping...
# Processing Record 11 of Set 1 | barrow
# OK
# Barrow
# OK
# Barrow
# City not found. Skipping...
# Processing Record 12 of Set 1 | rikitea
# OK
# Rikitea
# OK
# Rikitea
# City not found. Skipping...
# Processing Record 13 of Set 1 | punta arenas
# OK
# Punta Arenas
# OK
# Punta Arenas
# City not found. Skipping...
# Processing Record 14 of Set 1 | hithadhoo
# OK
# Hithadhoo
# OK
# Hithadhoo
# City not found. Skipping...
# Processing Record 15 of Set 1 | half moon bay
# OK
# Half Moon Bay
# OK
# Half Moon Bay
# City not found. Skipping...
# Processing Record 16 of Set 1 | norman wells
# OK
# Norman Wells
# OK
# Norman Wells
# City not found. Skipping...
# Processing Record 17 of Set 1 | illoqqortoormiut
# OK
# Illoqqortoormiut
# OK
# Illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | lazarev
# OK
# Lazarev
# OK
# Lazarev
# City not found. Skipping...
# Processing Record 19 of Set 1 | dong hoi
# OK
# Dong Hoi
# OK
# Dong Hoi
# City not found. Skipping...
# Processing Record 20 of Set 1 | upernavik
# OK
# Upernavik
# OK
# Upernavik
# City not found. Skipping...
# Processing Record 21 of Set 1 | nizhneyansk
# OK
# Nizhneyansk
# OK
# Nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | kalianget
# OK
# Kalianget
# OK
# Kalianget
# City not found. Skipping...
# Processing Record 23 of Set 1 | lebu
# OK
# Lebu
# OK
# Lebu
# City not found. Skipping...
# Processing Record 24 of Set 1 | dikson
# OK
# Dikson
# OK
# Dikson
# City not found. Skipping...
# Processing Record 25 of Set 1 | sisimiut
# OK
# Sisimiut
# OK
# Sisimiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | hami
# OK
# Hami
# OK
# Hami
# City not found. Skipping...
# Processing Record 27 of Set 1 | chuy
# OK
# Chuy
# OK
# Chuy
# City not found. Skipping...
# Processing Record 28 of Set 1 | kodiak
# OK
# Kodiak
# OK
# Kodiak
# City not found. Skipping...
# Processing Record 29 of Set 1 | samalaeulu
# OK
# Samalaeulu
# OK
# Samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 1 | kununurra
# OK
# Kununurra
# OK
# Kununurra
# City not found. Skipping...
# Processing Record 31 of Set 1 | albany
# OK
# Albany
# OK
# Albany
# City not found. Skipping...
# Processing Record 32 of Set 1 | mataura
# OK
# Mataura
# OK
# Mataura
# City not found. Skipping...
# Processing Record 33 of Set 1 | sokolo
# OK
# Sokolo
# OK
# Sokolo
# City not found. Skipping...
# Processing Record 34 of Set 1 | chaihe
# OK
# Chaihe
# OK
# Chaihe
# City not found. Skipping...
# Processing Record 35 of Set 1 | longyearbyen
# OK
# Longyearbyen
# OK
# Longyearbyen
# City not found. Skipping...
# Processing Record 36 of Set 1 | nikolskoye
# OK
# Nikolskoye
# OK
# Nikolskoye
# City not found. Skipping...
# Processing Record 37 of Set 1 | severo-kurilsk
# OK
# Severo-Kurilsk
# OK
# Severo-Kurilsk
# City not found. Skipping...
# Processing Record 38 of Set 1 | constitucion
# OK
# Constitucion
# OK
# Constitucion
# City not found. Skipping...
# Processing Record 39 of Set 1 | sao filipe
# OK
# Sao Filipe
# OK
# Sao Filipe
# City not found. Skipping...
# Processing Record 40 of Set 1 | torbay
# OK
# Torbay
# OK
# Torbay
# City not found. Skipping...
# Processing Record 41 of Set 1 | vaini
# OK
# Vaini
# OK
# Vaini
# City not found. Skipping...
# Processing Record 42 of Set 1 | bulolo
# OK
# Bulolo
# OK
# Bulolo
# City not found. Skipping...
# Processing Record 43 of Set 1 | sao miguel do araguaia
# OK
# Sao Miguel Do Araguaia
# OK
# Sao Miguel Do Araguaia
# City not found. Skipping...
# Processing Record 44 of Set 1 | jamestown
# OK
# Jamestown
# OK
# Jamestown
# City not found. Skipping...
# Processing Record 45 of Set 1 | saint-pierre
# OK
# Saint-Pierre
# OK
# Saint-Pierre
# City not found. Skipping...
# Processing Record 46 of Set 1 | butaritari
# OK
# Butaritari
# OK
# Butaritari
# City not found. Skipping...
# Processing Record 47 of Set 1 | shingu
# OK
# Shingu
# OK
# Shingu
# City not found. Skipping...
# Processing Record 48 of Set 1 | mangan
# OK
# Mangan
# OK
# Mangan
# City not found. Skipping...
# Processing Record 49 of Set 1 | busselton
# OK
# Busselton
# OK
# Busselton
# City not found. Skipping...
# Processing Record 50 of Set 1 | hobart
# OK
# Hobart
# OK
# Hobart
# City not found. Skipping...
# Processing Record 1 of Set 2 | hermanus
# OK
# Hermanus
# OK
# Hermanus
# Processing Record 2 of Set 2 | mys shmidta
# OK
# Mys Shmidta
# OK
# Mys Shmidta
# City not found. Skipping...
# Processing Record 3 of Set 2 | tsihombe
# OK
# Tsihombe
# OK
# Tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 2 | castro
# OK
# Castro
# OK
# Castro
# Processing Record 5 of Set 2 | yatou
# OK
# Yatou
# OK
# Yatou
# Processing Record 6 of Set 2 | kapuskasing
# OK
# Kapuskasing
# OK
# Kapuskasing
# Processing Record 7 of Set 2 | juneau
# OK
# Juneau
# OK
# Juneau
# Processing Record 8 of Set 2 | mugur-aksy
# OK
# Mugur-Aksy
# OK
# Mugur-Aksy
# Processing Record 9 of Set 2 | cabo san lucas
# OK
# Cabo San Lucas
# OK
# Cabo San Lucas
# Processing Record 10 of Set 2 | talnakh
# OK
# Talnakh
# OK
# Talnakh
# Processing Record 11 of Set 2 | bredasdorp
# OK
# Bredasdorp
# OK
# Bredasdorp
# Processing Record 12 of Set 2 | palmerston
# OK
# Palmerston
# OK
# Palmerston
# Processing Record 13 of Set 2 | coswig
# OK
# Coswig
# OK
# Coswig
# Processing Record 14 of Set 2 | longfeng
# OK
# Longfeng
# OK
# Longfeng
# Processing Record 15 of Set 2 | celestun
# OK
# Celestun
# OK
# Celestun
# Processing Record 16 of Set 2 | ilam
# OK
# Ilam
# OK
# Ilam
# Processing Record 17 of Set 2 | klaksvik
# OK
# Klaksvik
# OK
# Klaksvik
# Processing Record 18 of Set 2 | astana
# OK
# Astana
# OK
# Astana
# Processing Record 19 of Set 2 | beringovskiy
# OK
# Beringovskiy
# OK
# Beringovskiy
# Processing Record 20 of Set 2 | khatanga
# OK
# Khatanga
# OK
# Khatanga
# Processing Record 21 of Set 2 | port alfred
# OK
# Port Alfred
# OK
# Port Alfred
# Processing Record 22 of Set 2 | port elizabeth
# OK
# Port Elizabeth
# OK
# Port Elizabeth
# Processing Record 23 of Set 2 | qaanaaq
# OK
# Qaanaaq
# OK
# Qaanaaq
# Processing Record 24 of Set 2 | amderma
# OK
# Amderma
# OK
# Amderma
# City not found. Skipping...
# Processing Record 25 of Set 2 | chokurdakh
# OK
# Chokurdakh
# OK
# Chokurdakh
# Processing Record 26 of Set 2 | straumen
# OK
# Straumen
# OK
# Straumen
# Processing Record 27 of Set 2 | provideniya
# OK
# Provideniya
# OK
# Provideniya
# Processing Record 28 of Set 2 | malindi
# OK
# Malindi
# OK
# Malindi
# Processing Record 29 of Set 2 | barentsburg
# OK
# Barentsburg
# OK
# Barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 2 | westport
# OK
# Westport
# OK
# Westport
# Processing Record 31 of Set 2 | puerto ayora
# OK
# Puerto Ayora
# OK
# Puerto Ayora
# Processing Record 32 of Set 2 | santa rosa de viterbo
# OK
# Santa Rosa De Viterbo
# OK
# Santa Rosa De Viterbo
# Processing Record 33 of Set 2 | souillac
# OK
# Souillac
# OK
# Souillac
# Processing Record 34 of Set 2 | kenai
# OK
# Kenai
# OK
# Kenai
# Processing Record 35 of Set 2 | whitehorse
# OK
# Whitehorse
# OK
# Whitehorse
# Processing Record 36 of Set 2 | erdenet
# OK
# Erdenet
# OK
# Erdenet
# Processing Record 37 of Set 2 | mitsamiouli
# OK
# Mitsamiouli
# OK
# Mitsamiouli
# Processing Record 38 of Set 2 | nome
# OK
# Nome
# OK
# Nome
# Processing Record 39 of Set 2 | teya
# OK
# Teya
# OK
# Teya
# Processing Record 40 of Set 2 | charagua
# OK
# Charagua
# OK
# Charagua
# Processing Record 41 of Set 2 | saldanha
# OK
# Saldanha
# OK
# Saldanha
# Processing Record 42 of Set 2 | kilindoni
# OK
# Kilindoni
# OK
# Kilindoni
# Processing Record 43 of Set 2 | ust-tsilma
# OK
# Ust-Tsilma
# OK
# Ust-Tsilma
# Processing Record 44 of Set 2 | fortuna
# OK
# Fortuna
# OK
# Fortuna
# Processing Record 45 of Set 2 | bandarbeyla
# OK
# Bandarbeyla
# OK
# Bandarbeyla
# Processing Record 46 of Set 2 | ambatondrazaka
# OK
# Ambatondrazaka
# OK
# Ambatondrazaka
# Processing Record 47 of Set 2 | kyabram
# OK
# Kyabram
# OK
# Kyabram
# Processing Record 48 of Set 2 | atuona
# OK
# Atuona
# OK
# Atuona
# Processing Record 49 of Set 2 | kulhudhuffushi
# OK
# Kulhudhuffushi
# OK
# Kulhudhuffushi
# Processing Record 50 of Set 2 | vestmannaeyjar
# OK
# Vestmannaeyjar
# OK
# Vestmannaeyjar
# Processing Record 1 of Set 3 | tiksi
# OK
# Tiksi
# OK
# Tiksi
# Processing Record 2 of Set 3 | ahipara
# OK
# Ahipara
# OK
# Ahipara
# Processing Record 3 of Set 3 | bluff
# OK
# Bluff
# OK
# Bluff
# Processing Record 4 of Set 3 | saskylakh
# OK
# Saskylakh
# OK
# Saskylakh
# Processing Record 5 of Set 3 | el mante
# OK
# El Mante
# OK
# El Mante
# Processing Record 6 of Set 3 | husavik
# OK
# Husavik
# OK
# Husavik
# Processing Record 7 of Set 3 | airai
# OK
# Airai
# OK
# Airai
# Processing Record 8 of Set 3 | leningradskiy
# OK
# Leningradskiy
# OK
# Leningradskiy
# Processing Record 9 of Set 3 | ulety
# OK
# Ulety
# OK
# Ulety
# Processing Record 10 of Set 3 | bathsheba
# OK
# Bathsheba
# OK
# Bathsheba
# Processing Record 11 of Set 3 | verkhnyaya inta
# OK
# Verkhnyaya Inta
# OK
# Verkhnyaya Inta
# Processing Record 12 of Set 3 | dallas
# OK
# Dallas
# OK
# Dallas
# Processing Record 13 of Set 3 | zabaykalsk
# OK
# Zabaykalsk
# OK
# Zabaykalsk
# Processing Record 14 of Set 3 | the valley
# OK
# The Valley
# OK
# The Valley
# Processing Record 15 of Set 3 | garden city
# OK
# Garden City
# OK
# Garden City
# Processing Record 16 of Set 3 | yantai
# OK
# Yantai
# OK
# Yantai
# Processing Record 17 of Set 3 | saint-philippe
# OK
# Saint-Philippe
# OK
# Saint-Philippe
# Processing Record 18 of Set 3 | coihaique
# OK
# Coihaique
# OK
# Coihaique
# Processing Record 19 of Set 3 | fier
# OK
# Fier
# OK
# Fier
# Processing Record 20 of Set 3 | mount vernon
# OK
# Mount Vernon
# OK
# Mount Vernon
# Processing Record 21 of Set 3 | porto novo
# OK
# Porto Novo
# OK
# Porto Novo
# Processing Record 22 of Set 3 | mahebourg
# OK
# Mahebourg
# OK
# Mahebourg
# Processing Record 23 of Set 3 | hilo
# OK
# Hilo
# OK
# Hilo
# Processing Record 24 of Set 3 | novochernorechenskiy
# OK
# Novochernorechenskiy
# OK
# Novochernorechenskiy
# Processing Record 25 of Set 3 | avera
# OK
# Avera
# OK
# Avera
# Processing Record 26 of Set 3 | atar
# OK
# Atar
# OK
# Atar
# Processing Record 27 of Set 3 | ponta do sol
# OK
# Ponta Do Sol
# OK
# Ponta Do Sol
# Processing Record 28 of Set 3 | luau
# OK
# Luau
# OK
# Luau
# Processing Record 29 of Set 3 | cidreira
# OK
# Cidreira
# OK
# Cidreira
# Processing Record 30 of Set 3 | hay river
# OK
# Hay River
# OK
# Hay River
# Processing Record 31 of Set 3 | bolungarvik
# OK
# Bolungarvik
# OK
# Bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 3 | mehamn
# OK
# Mehamn
# OK
# Mehamn
# Processing Record 33 of Set 3 | elesbao veloso
# OK
# Elesbao Veloso
# OK
# Elesbao Veloso
# Processing Record 34 of Set 3 | riyadh
# OK
# Riyadh
# OK
# Riyadh
# Processing Record 35 of Set 3 | pisco
# OK
# Pisco
# OK
# Pisco
# Processing Record 36 of Set 3 | xai-xai
# OK
# Xai-Xai
# OK
# Xai-Xai
# Processing Record 37 of Set 3 | srednekolymsk
# OK
# Srednekolymsk
# OK
# Srednekolymsk
# Processing Record 38 of Set 3 | hofn
# OK
# Hofn
# OK
# Hofn
# Processing Record 39 of Set 3 | aswan
# OK
# Aswan
# OK
# Aswan
# Processing Record 40 of Set 3 | thompson
# OK
# Thompson
# OK
# Thompson
# Processing Record 41 of Set 3 | toyooka
# OK
# Toyooka
# OK
# Toyooka
# Processing Record 42 of Set 3 | egvekinot
# OK
# Egvekinot
# OK
# Egvekinot
# Processing Record 43 of Set 3 | attawapiskat
# OK
# Attawapiskat
# OK
# Attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 3 | kichmengskiy gorodok
# OK
# Kichmengskiy Gorodok
# OK
# Kichmengskiy Gorodok
# Processing Record 45 of Set 3 | muroto
# OK
# Muroto
# OK
# Muroto
# Processing Record 46 of Set 3 | hualmay
# OK
# Hualmay
# OK
# Hualmay
# Processing Record 47 of Set 3 | nyurba
# OK
# Nyurba
# OK
# Nyurba
# Processing Record 48 of Set 3 | bethel
# OK
# Bethel
# OK
# Bethel
# Processing Record 49 of Set 3 | clyde river
# OK
# Clyde River
# OK
# Clyde River
# Processing Record 50 of Set 3 | lufilufi
# OK
# Lufilufi
# OK
# Lufilufi
# Processing Record 1 of Set 4 | ambon
# OK
# Ambon
# OK
# Ambon
# Processing Record 2 of Set 4 | bhindar
# OK
# Bhindar
# OK
# Bhindar
# Processing Record 3 of Set 4 | bambous virieux
# OK
# Bambous Virieux
# OK
# Bambous Virieux
# Processing Record 4 of Set 4 | krasnoselkup
# OK
# Krasnoselkup
# OK
# Krasnoselkup
# Processing Record 5 of Set 4 | avarua
# OK
# Avarua
# OK
# Avarua
# Processing Record 6 of Set 4 | kagadi
# OK
# Kagadi
# OK
# Kagadi
# Processing Record 7 of Set 4 | emerald
# OK
# Emerald
# OK
# Emerald
# Processing Record 8 of Set 4 | vrangel
# OK
# Vrangel
# OK
# Vrangel
# Processing Record 9 of Set 4 | ijaki
# OK
# Ijaki
# OK
# Ijaki
# City not found. Skipping...
# Processing Record 10 of Set 4 | sur
# OK
# Sur
# OK
# Sur
# Processing Record 11 of Set 4 | moron
# OK
# Moron
# OK
# Moron
# Processing Record 12 of Set 4 | christchurch
# OK
# Christchurch
# OK
# Christchurch
# Processing Record 13 of Set 4 | gunnedah
# OK
# Gunnedah
# OK
# Gunnedah
# Processing Record 14 of Set 4 | weifang
# OK
# Weifang
# OK
# Weifang
# Processing Record 15 of Set 4 | fomboni
# OK
# Fomboni
# OK
# Fomboni
# Processing Record 16 of Set 4 | argelia
# OK
# Argelia
# OK
# Argelia
# Processing Record 17 of Set 4 | rio gallegos
# OK
# Rio Gallegos
# OK
# Rio Gallegos
# Processing Record 18 of Set 4 | palabuhanratu
# OK
# Palabuhanratu
# OK
# Palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 4 | svetlogorsk
# OK
# Svetlogorsk
# OK
# Svetlogorsk
# Processing Record 20 of Set 4 | sola
# OK
# Sola
# OK
# Sola
# Processing Record 21 of Set 4 | roebourne
# OK
# Roebourne
# OK
# Roebourne
# Processing Record 22 of Set 4 | jumla
# OK
# Jumla
# OK
# Jumla
# Processing Record 23 of Set 4 | guerrero negro
# OK
# Guerrero Negro
# OK
# Guerrero Negro
# Processing Record 24 of Set 4 | sertanopolis
# OK
# Sertanopolis
# OK
# Sertanopolis
# Processing Record 25 of Set 4 | omboue
# OK
# Omboue
# OK
# Omboue
# Processing Record 26 of Set 4 | dubno
# OK
# Dubno
# OK
# Dubno
# Processing Record 27 of Set 4 | conchagua
# OK
# Conchagua
# OK
# Conchagua
# Processing Record 28 of Set 4 | fallon
# OK
# Fallon
# OK
# Fallon
# Processing Record 29 of Set 4 | sidi ali
# OK
# Sidi Ali
# OK
# Sidi Ali
# Processing Record 30 of Set 4 | pevek
# OK
# Pevek
# OK
# Pevek
# Processing Record 31 of Set 4 | san rafael
# OK
# San Rafael
# OK
# San Rafael
# Processing Record 32 of Set 4 | coos bay
# OK
# Coos Bay
# OK
# Coos Bay
# Processing Record 33 of Set 4 | kazalinsk
# OK
# Kazalinsk
# OK
# Kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 4 | copiapo
# OK
# Copiapo
# OK
# Copiapo
# Processing Record 35 of Set 4 | salamiyah
# OK
# Salamiyah
# OK
# Salamiyah
# Processing Record 36 of Set 4 | calderitas
# OK
# Calderitas
# OK
# Calderitas
# Processing Record 37 of Set 4 | talaya
# OK
# Talaya
# OK
# Talaya
# Processing Record 38 of Set 4 | new norfolk
# OK
# New Norfolk
# OK
# New Norfolk
# Processing Record 39 of Set 4 | humaita
# OK
# Humaita
# OK
# Humaita
# Processing Record 40 of Set 4 | hasaki
# OK
# Hasaki
# OK
# Hasaki
# Processing Record 41 of Set 4 | victoria
# OK
# Victoria
# OK
# Victoria
# Processing Record 42 of Set 4 | waldoboro
# OK
# Waldoboro
# OK
# Waldoboro
# Processing Record 43 of Set 4 | meadow lake
# OK
# Meadow Lake
# OK
# Meadow Lake
# Processing Record 44 of Set 4 | mount isa
# OK
# Mount Isa
# OK
# Mount Isa
# Processing Record 45 of Set 4 | melilla
# OK
# Melilla
# OK
# Melilla
# Processing Record 46 of Set 4 | imbituba
# OK
# Imbituba
# OK
# Imbituba
# Processing Record 47 of Set 4 | luderitz
# OK
# Luderitz
# OK
# Luderitz
# Processing Record 48 of Set 4 | ascension
# OK
# Ascension
# OK
# Ascension
# Processing Record 49 of Set 4 | tuktoyaktuk
# OK
# Tuktoyaktuk
# OK
# Tuktoyaktuk
# Processing Record 50 of Set 4 | manzhouli
# OK
# Manzhouli
# OK
# Manzhouli
# Processing Record 1 of Set 5 | mbekenyera
# OK
# Mbekenyera
# OK
# Mbekenyera
# Processing Record 2 of Set 5 | los llanos de aridane
# OK
# Los Llanos De Aridane
# OK
# Los Llanos De Aridane
# Processing Record 3 of Set 5 | panalingaan
# OK
# Panalingaan
# OK
# Panalingaan
# Processing Record 4 of Set 5 | saint-georges
# OK
# Saint-Georges
# OK
# Saint-Georges
# Processing Record 5 of Set 5 | kaitangata
# OK
# Kaitangata
# OK
# Kaitangata
# Processing Record 6 of Set 5 | constantine
# OK
# Constantine
# OK
# Constantine
# Processing Record 7 of Set 5 | krasnoarmeysk
# OK
# Krasnoarmeysk
# OK
# Krasnoarmeysk
# Processing Record 8 of Set 5 | copacabana
# OK
# Copacabana
# OK
# Copacabana
# Processing Record 9 of Set 5 | villacarrillo
# OK
# Villacarrillo
# OK
# Villacarrillo
# Processing Record 10 of Set 5 | champerico
# OK
# Champerico
# OK
# Champerico
# Processing Record 11 of Set 5 | uruacu
# OK
# Uruacu
# OK
# Uruacu
# Processing Record 12 of Set 5 | te anau
# OK
# Te Anau
# OK
# Te Anau
# Processing Record 13 of Set 5 | faanui
# OK
# Faanui
# OK
# Faanui
# Processing Record 14 of Set 5 | itarema
# OK
# Itarema
# OK
# Itarema
# Processing Record 15 of Set 5 | sibu
# OK
# Sibu
# OK
# Sibu
# Processing Record 16 of Set 5 | harper
# OK
# Harper
# OK
# Harper
# Processing Record 17 of Set 5 | san salvo
# OK
# San Salvo
# OK
# San Salvo
# Processing Record 18 of Set 5 | samusu
# OK
# Samusu
# OK
# Samusu
# City not found. Skipping...
# Processing Record 19 of Set 5 | mar del plata
# OK
# Mar Del Plata
# OK
# Mar Del Plata
# Processing Record 20 of Set 5 | popondetta
# OK
# Popondetta
# OK
# Popondetta
# Processing Record 21 of Set 5 | praia da vitoria
# OK
# Praia Da Vitoria
# OK
# Praia Da Vitoria
# Processing Record 22 of Set 5 | grindavik
# OK
# Grindavik
# OK
# Grindavik
# Processing Record 23 of Set 5 | chaplynka
# OK
# Chaplynka
# OK
# Chaplynka
# Processing Record 24 of Set 5 | arlit
# OK
# Arlit
# OK
# Arlit
# Processing Record 25 of Set 5 | faya
# OK
# Faya
# OK
# Faya
# Processing Record 26 of Set 5 | rawson
# OK
# Rawson
# OK
# Rawson
# Processing Record 27 of Set 5 | sol-iletsk
# OK
# Sol-Iletsk
# OK
# Sol-Iletsk
# Processing Record 28 of Set 5 | cape town
# OK
# Cape Town
# OK
# Cape Town
# Processing Record 29 of Set 5 | ostrovnoy
# OK
# Ostrovnoy
# OK
# Ostrovnoy
# Processing Record 30 of Set 5 | flin flon
# OK
# Flin Flon
# OK
# Flin Flon
# Processing Record 31 of Set 5 | stornoway
# OK
# Stornoway
# OK
# Stornoway
# Processing Record 32 of Set 5 | margate
# OK
# Margate
# OK
# Margate
# Processing Record 33 of Set 5 | santa vitoria
# OK
# Santa Vitoria
# OK
# Santa Vitoria
# Processing Record 34 of Set 5 | el alto
# OK
# El Alto
# OK
# El Alto
# Processing Record 35 of Set 5 | high level
# OK
# High Level
# OK
# High Level
# Processing Record 36 of Set 5 | sibanicu
# OK
# Sibanicu
# OK
# Sibanicu
# Processing Record 37 of Set 5 | vestmanna
# OK
# Vestmanna
# OK
# Vestmanna
# Processing Record 38 of Set 5 | geraldton
# OK
# Geraldton
# OK
# Geraldton
# Processing Record 39 of Set 5 | carnarvon
# OK
# Carnarvon
# OK
# Carnarvon
# Processing Record 40 of Set 5 | zeya
# OK
# Zeya
# OK
# Zeya
# Processing Record 41 of Set 5 | havelock
# OK
# Havelock
# OK
# Havelock
# Processing Record 42 of Set 5 | basco
# OK
# Basco
# OK
# Basco
# Processing Record 43 of Set 5 | uvinza
# OK
# Uvinza
# OK
# Uvinza
# Processing Record 44 of Set 5 | gamba
# OK
# Gamba
# OK
# Gamba
# Processing Record 45 of Set 5 | tabiauea
# OK
# Tabiauea
# OK
# Tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 5 | victor harbor
# OK
# Victor Harbor
# OK
# Victor Harbor
# Processing Record 47 of Set 5 | iskateley
# OK
# Iskateley
# OK
# Iskateley
# Processing Record 48 of Set 5 | pinega
# OK
# Pinega
# OK
# Pinega
# Processing Record 49 of Set 5 | sorvag
# OK
# Sorvag
# OK
# Sorvag
# City not found. Skipping...
# Processing Record 50 of Set 5 | papetoai
# OK
# Papetoai
# OK
# Papetoai
# Processing Record 1 of Set 6 | mecca
# OK
# Mecca
# OK
# Mecca
# Processing Record 2 of Set 6 | boa vista
# OK
# Boa Vista
# OK
# Boa Vista
# Processing Record 3 of Set 6 | broome
# OK
# Broome
# OK
# Broome
# Processing Record 4 of Set 6 | slave lake
# OK
# Slave Lake
# OK
# Slave Lake
# Processing Record 5 of Set 6 | stephenville
# OK
# Stephenville
# OK
# Stephenville
# Processing Record 6 of Set 6 | ponta delgada
# OK
# Ponta Delgada
# OK
# Ponta Delgada
# Processing Record 7 of Set 6 | belushya guba
# OK
# Belushya Guba
# OK
# Belushya Guba
# City not found. Skipping...
# Processing Record 8 of Set 6 | cayenne
# OK
# Cayenne
# OK
# Cayenne
# Processing Record 9 of Set 6 | odweyne
# OK
# Odweyne
# OK
# Odweyne
# Processing Record 10 of Set 6 | muisne
# OK
# Muisne
# OK
# Muisne
# Processing Record 11 of Set 6 | balkanabat
# OK
# Balkanabat
# OK
# Balkanabat
# Processing Record 12 of Set 6 | ornskoldsvik
# OK
# Ornskoldsvik
# OK
# Ornskoldsvik
# Processing Record 13 of Set 6 | barra da estiva
# OK
# Barra Da Estiva
# OK
# Barra Da Estiva
# Processing Record 14 of Set 6 | kerrville
# OK
# Kerrville
# OK
# Kerrville
# Processing Record 15 of Set 6 | port lincoln
# OK
# Port Lincoln
# OK
# Port Lincoln
# Processing Record 16 of Set 6 | dingle
# OK
# Dingle
# OK
# Dingle
# Processing Record 17 of Set 6 | golden
# OK
# Golden
# OK
# Golden
# Processing Record 18 of Set 6 | kupang
# OK
# Kupang
# OK
# Kupang
# Processing Record 19 of Set 6 | aguimes
# OK
# Aguimes
# OK
# Aguimes
# Processing Record 20 of Set 6 | socorro
# OK
# Socorro
# OK
# Socorro
# Processing Record 21 of Set 6 | alofi
# OK
# Alofi
# OK
# Alofi
# Processing Record 22 of Set 6 | tessalit
# OK
# Tessalit
# OK
# Tessalit
# Processing Record 23 of Set 6 | kyaikkami
# OK
# Kyaikkami
# OK
# Kyaikkami
# Processing Record 24 of Set 6 | nola
# OK
# Nola
# OK
# Nola
# Processing Record 25 of Set 6 | yomitan
# OK
# Yomitan
# OK
# Yomitan
# City not found. Skipping...
# Processing Record 26 of Set 6 | praia
# OK
# Praia
# OK
# Praia
# Processing Record 27 of Set 6 | nemuro
# OK
# Nemuro
# OK
# Nemuro
# Processing Record 28 of Set 6 | bela
# OK
# Bela
# OK
# Bela
# Processing Record 29 of Set 6 | tual
# OK
# Tual
# OK
# Tual
# Processing Record 30 of Set 6 | kisesa
# OK
# Kisesa
# OK
# Kisesa
# Processing Record 31 of Set 6 | tabialan
# OK
# Tabialan
# OK
# Tabialan
# City not found. Skipping...
# Processing Record 32 of Set 6 | le port
# OK
# Le Port
# OK
# Le Port
# Processing Record 33 of Set 6 | kedrovyy
# OK
# Kedrovyy
# OK
# Kedrovyy
# Processing Record 34 of Set 6 | provost
# OK
# Provost
# OK
# Provost
# Processing Record 35 of Set 6 | east london
# OK
# East London
# OK
# East London
# Processing Record 36 of Set 6 | balkhash
# OK
# Balkhash
# OK
# Balkhash
# Processing Record 37 of Set 6 | allapalli
# OK
# Allapalli
# OK
# Allapalli
# Processing Record 38 of Set 6 | burns lake
# OK
# Burns Lake
# OK
# Burns Lake
# Processing Record 39 of Set 6 | arraial do cabo
# OK
# Arraial Do Cabo
# OK
# Arraial Do Cabo
# Processing Record 40 of Set 6 | sao joao da barra
# OK
# Sao Joao Da Barra
# OK
# Sao Joao Da Barra
# Processing Record 41 of Set 6 | quang ngai
# OK
# Quang Ngai
# OK
# Quang Ngai
# Processing Record 42 of Set 6 | bichena
# OK
# Bichena
# OK
# Bichena
# Processing Record 43 of Set 6 | andenes
# OK
# Andenes
# OK
# Andenes
# Processing Record 44 of Set 6 | tawzar
# OK
# Tawzar
# OK
# Tawzar
# City not found. Skipping...
# Processing Record 45 of Set 6 | marzuq
# OK
# Marzuq
# OK
# Marzuq
# Processing Record 46 of Set 6 | belyy yar
# OK
# Belyy Yar
# OK
# Belyy Yar
# Processing Record 47 of Set 6 | salalah
# OK
# Salalah
# OK
# Salalah
# Processing Record 48 of Set 6 | peniche
# OK
# Peniche
# OK
# Peniche
# Processing Record 49 of Set 6 | nanortalik
# OK
# Nanortalik
# OK
# Nanortalik
# Processing Record 50 of Set 6 | cherskiy
# OK
# Cherskiy
# OK
# Cherskiy
# Processing Record 1 of Set 7 | worland
# OK
# Worland
# OK
# Worland
# Processing Record 2 of Set 7 | port hedland
# OK
# Port Hedland
# OK
# Port Hedland
# Processing Record 3 of Set 7 | samarai
# OK
# Samarai
# OK
# Samarai
# Processing Record 4 of Set 7 | urdoma
# OK
# Urdoma
# OK
# Urdoma
# Processing Record 5 of Set 7 | tikalaan
# OK
# Tikalaan
# OK
# Tikalaan
# City not found. Skipping...
# Processing Record 6 of Set 7 | sarangarh
# OK
# Sarangarh
# OK
# Sarangarh
# Processing Record 7 of Set 7 | anadyr
# OK
# Anadyr
# OK
# Anadyr
# Processing Record 8 of Set 7 | yarim
# OK
# Yarim
# OK
# Yarim
# Processing Record 9 of Set 7 | norrkoping
# OK
# Norrkoping
# OK
# Norrkoping
# Processing Record 10 of Set 7 | qaqortoq
# OK
# Qaqortoq
# OK
# Qaqortoq
# Processing Record 11 of Set 7 | saint-joseph
# OK
# Saint-Joseph
# OK
# Saint-Joseph
# Processing Record 12 of Set 7 | coquimbo
# OK
# Coquimbo
# OK
# Coquimbo
# Processing Record 13 of Set 7 | cairns
# OK
# Cairns
# OK
# Cairns
# Processing Record 14 of Set 7 | chico
# OK
# Chico
# OK
# Chico
# Processing Record 15 of Set 7 | hermosillo
# OK
# Hermosillo
# OK
# Hermosillo
# Processing Record 16 of Set 7 | san andres
# OK
# San Andres
# OK
# San Andres
# Processing Record 17 of Set 7 | darnah
# OK
# Darnah
# OK
# Darnah
# Processing Record 18 of Set 7 | harwich
# OK
# Harwich
# OK
# Harwich
# Processing Record 19 of Set 7 | sault sainte marie
# OK
# Sault Sainte Marie
# OK
# Sault Sainte Marie
# Processing Record 20 of Set 7 | bridgend
# OK
# Bridgend
# OK
# Bridgend
# Processing Record 21 of Set 7 | methoni
# OK
# Methoni
# OK
# Methoni
# Processing Record 22 of Set 7 | malinovoye ozero
# OK
# Malinovoye Ozero
# OK
# Malinovoye Ozero
# Processing Record 23 of Set 7 | kachiry
# OK
# Kachiry
# OK
# Kachiry
# Processing Record 24 of Set 7 | van wert
# OK
# Van Wert
# OK
# Van Wert
# Processing Record 25 of Set 7 | hajnowka
# OK
# Hajnowka
# OK
# Hajnowka
# Processing Record 26 of Set 7 | roma
# OK
# Roma
# OK
# Roma
# Processing Record 27 of Set 7 | monrovia
# OK
# Monrovia
# OK
# Monrovia
# Processing Record 28 of Set 7 | leh
# OK
# Leh
# OK
# Leh
# Processing Record 29 of Set 7 | valdivia
# OK
# Valdivia
# OK
# Valdivia
# Processing Record 30 of Set 7 | bella union
# OK
# Bella Union
# OK
# Bella Union
# Processing Record 31 of Set 7 | zemio
# OK
# Zemio
# OK
# Zemio
# Processing Record 32 of Set 7 | ballina
# OK
# Ballina
# OK
# Ballina
# Processing Record 33 of Set 7 | kaduna
# OK
# Kaduna
# OK
# Kaduna
# Processing Record 34 of Set 7 | montalban
# OK
# Montalban
# OK
# Montalban
# Processing Record 35 of Set 7 | tura
# OK
# Tura
# OK
# Tura
# Processing Record 36 of Set 7 | katsuura
# OK
# Katsuura
# OK
# Katsuura
# Processing Record 37 of Set 7 | supe
# OK
# Supe
# OK
# Supe
# Processing Record 38 of Set 7 | port blair
# OK
# Port Blair
# OK
# Port Blair
# Processing Record 39 of Set 7 | rawannawi
# OK
# Rawannawi
# OK
# Rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 7 | lincoln
# OK
# Lincoln
# OK
# Lincoln
# Processing Record 41 of Set 7 | karpogory
# OK
# Karpogory
# OK
# Karpogory
# Processing Record 42 of Set 7 | minab
# OK
# Minab
# OK
# Minab
# Processing Record 43 of Set 7 | jagtial
# OK
# Jagtial
# OK
# Jagtial
# Processing Record 44 of Set 7 | chicama
# OK
# Chicama
# OK
# Chicama
# Processing Record 45 of Set 7 | nelson bay
# OK
# Nelson Bay
# OK
# Nelson Bay
# Processing Record 46 of Set 7 | brae
# OK
# Brae
# OK
# Brae
# Processing Record 47 of Set 7 | karratha
# OK
# Karratha
# OK
# Karratha
# Processing Record 48 of Set 7 | codrington
# OK
# Codrington
# OK
# Codrington
# Processing Record 49 of Set 7 | muros
# OK
# Muros
# OK
# Muros
# Processing Record 50 of Set 7 | taywarah
# OK
# Taywarah
# OK
# Taywarah
# Processing Record 1 of Set 8 | binabalian
# OK
# Binabalian
# OK
# Binabalian
# Processing Record 2 of Set 8 | bengkulu
# OK
# Bengkulu
# OK
# Bengkulu
# Processing Record 3 of Set 8 | paicandu
# OK
# Paicandu
# OK
# Paicandu
# Processing Record 4 of Set 8 | labytnangi
# OK
# Labytnangi
# OK
# Labytnangi
# Processing Record 5 of Set 8 | wakkanai
# OK
# Wakkanai
# OK
# Wakkanai
# Processing Record 6 of Set 8 | upata
# OK
# Upata
# OK
# Upata
# Processing Record 7 of Set 8 | batagay
# OK
# Batagay
# OK
# Batagay
# Processing Record 8 of Set 8 | ulsteinvik
# OK
# Ulsteinvik
# OK
# Ulsteinvik
# Processing Record 9 of Set 8 | yorkton
# OK
# Yorkton
# OK
# Yorkton
# Processing Record 10 of Set 8 | vostok
# OK
# Vostok
# OK
# Vostok
# Processing Record 11 of Set 8 | muli
# OK
# Muli
# OK
# Muli
# Processing Record 12 of Set 8 | chipinge
# OK
# Chipinge
# OK
# Chipinge
# Processing Record 13 of Set 8 | noumea
# OK
# Noumea
# OK
# Noumea
# Processing Record 14 of Set 8 | xochihuehuetlan
# OK
# Xochihuehuetlan
# OK
# Xochihuehuetlan
# Processing Record 15 of Set 8 | inirida
# OK
# Inirida
# OK
# Inirida
# Processing Record 16 of Set 8 | lagoa
# OK
# Lagoa
# OK
# Lagoa
# Processing Record 17 of Set 8 | esperance
# OK
# Esperance
# OK
# Esperance
# Processing Record 18 of Set 8 | manglisi
# OK
# Manglisi
# OK
# Manglisi
# Processing Record 19 of Set 8 | fonte boa
# OK
# Fonte Boa
# OK
# Fonte Boa
# Processing Record 20 of Set 8 | arys
# OK
# Arys
# OK
# Arys
# Processing Record 21 of Set 8 | miajadas
# OK
# Miajadas
# OK
# Miajadas
# Processing Record 22 of Set 8 | nueve de julio
# OK
# Nueve De Julio
# OK
# Nueve De Julio
# Processing Record 23 of Set 8 | vasylivka
# OK
# Vasylivka
# OK
# Vasylivka
# Processing Record 24 of Set 8 | banda aceh
# OK
# Banda Aceh
# OK
# Banda Aceh
# Processing Record 25 of Set 8 | gazanjyk
# OK
# Gazanjyk
# OK
# Gazanjyk
# Processing Record 26 of Set 8 | saleaula
# OK
# Saleaula
# OK
# Saleaula
# City not found. Skipping...
# Processing Record 27 of Set 8 | luena
# OK
# Luena
# OK
# Luena
# Processing Record 28 of Set 8 | iquitos
# OK
# Iquitos
# OK
# Iquitos
# Processing Record 29 of Set 8 | taitung
# OK
# Taitung
# OK
# Taitung
# Processing Record 30 of Set 8 | deputatskiy
# OK
# Deputatskiy
# OK
# Deputatskiy
# Processing Record 31 of Set 8 | san cristobal
# OK
# San Cristobal
# OK
# San Cristobal
# Processing Record 32 of Set 8 | diego de almagro
# OK
# Diego De Almagro
# OK
# Diego De Almagro
# Processing Record 33 of Set 8 | emba
# OK
# Emba
# OK
# Emba
# Processing Record 34 of Set 8 | marcona
# OK
# Marcona
# OK
# Marcona
# City not found. Skipping...
# Processing Record 35 of Set 8 | hobyo
# OK
# Hobyo
# OK
# Hobyo
# Processing Record 36 of Set 8 | narsaq
# OK
# Narsaq
# OK
# Narsaq
# Processing Record 37 of Set 8 | greeneville
# OK
# Greeneville
# OK
# Greeneville
# Processing Record 38 of Set 8 | vaitupu
# OK
# Vaitupu
# OK
# Vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 8 | curanilahue
# OK
# Curanilahue
# OK
# Curanilahue
# Processing Record 40 of Set 8 | os
# OK
# Os
# OK
# Os
# City not found. Skipping...
# Processing Record 41 of Set 8 | lokosovo
# OK
# Lokosovo
# OK
# Lokosovo
# Processing Record 42 of Set 8 | jarjis
# OK
# Jarjis
# OK
# Jarjis
# City not found. Skipping...
# Processing Record 43 of Set 8 | visnes
# OK
# Visnes
# OK
# Visnes
# Processing Record 44 of Set 8 | timmins
# OK
# Timmins
# OK
# Timmins
# Processing Record 45 of Set 8 | lethem
# OK
# Lethem
# OK
# Lethem
# Processing Record 46 of Set 8 | mutis
# OK
# Mutis
# OK
# Mutis
# Processing Record 47 of Set 8 | havoysund
# OK
# Havoysund
# OK
# Havoysund
# Processing Record 48 of Set 8 | gizo
# OK
# Gizo
# OK
# Gizo
# Processing Record 49 of Set 8 | doha
# OK
# Doha
# OK
# Doha
# Processing Record 50 of Set 8 | bubaque
# OK
# Bubaque
# OK
# Bubaque
# Processing Record 1 of Set 9 | iwaki
# OK
# Iwaki
# OK
# Iwaki
# Processing Record 2 of Set 9 | bargal
# OK
# Bargal
# OK
# Bargal
# City not found. Skipping...
# Processing Record 3 of Set 9 | kavieng
# OK
# Kavieng
# OK
# Kavieng
# Processing Record 4 of Set 9 | lavrentiya
# OK
# Lavrentiya
# OK
# Lavrentiya
# Processing Record 5 of Set 9 | dulyapino
# OK
# Dulyapino
# OK
# Dulyapino
# Processing Record 6 of Set 9 | paragominas
# OK
# Paragominas
# OK
# Paragominas
# Processing Record 7 of Set 9 | vao
# OK
# Vao
# OK
# Vao
# Processing Record 8 of Set 9 | haltom city
# OK
# Haltom City
# OK
# Haltom City
# Processing Record 9 of Set 9 | byron bay
# OK
# Byron Bay
# OK
# Byron Bay
# Processing Record 10 of Set 9 | ilulissat
# OK
# Ilulissat
# OK
# Ilulissat
# Processing Record 11 of Set 9 | brisbane
# OK
# Brisbane
# OK
# Brisbane
# Processing Record 12 of Set 9 | waipawa
# OK
# Waipawa
# OK
# Waipawa
# Processing Record 13 of Set 9 | nguiu
# OK
# Nguiu
# OK
# Nguiu
# City not found. Skipping...
# Processing Record 14 of Set 9 | bremerton
# OK
# Bremerton
# OK
# Bremerton
# Processing Record 15 of Set 9 | san patricio
# OK
# San Patricio
# OK
# San Patricio
# Processing Record 16 of Set 9 | kupino
# OK
# Kupino
# OK
# Kupino
# Processing Record 17 of Set 9 | bacolod
# OK
# Bacolod
# OK
# Bacolod
# Processing Record 18 of Set 9 | sayyan
# OK
# Sayyan
# OK
# Sayyan
# Processing Record 19 of Set 9 | rungata
# OK
# Rungata
# OK
# Rungata
# City not found. Skipping...
# Processing Record 20 of Set 9 | linxia
# OK
# Linxia
# OK
# Linxia
# Processing Record 21 of Set 9 | bell ville
# OK
# Bell Ville
# OK
# Bell Ville
# Processing Record 22 of Set 9 | saint george
# OK
# Saint George
# OK
# Saint George
# Processing Record 23 of Set 9 | kieta
# OK
# Kieta
# OK
# Kieta
# Processing Record 24 of Set 9 | bako
# OK
# Bako
# OK
# Bako
# Processing Record 25 of Set 9 | talcahuano
# OK
# Talcahuano
# OK
# Talcahuano
# Processing Record 26 of Set 9 | srednebelaya
# OK
# Srednebelaya
# OK
# Srednebelaya
# Processing Record 27 of Set 9 | georgetown
# OK
# Georgetown
# OK
# Georgetown
# Processing Record 28 of Set 9 | port pirie
# OK
# Port Pirie
# OK
# Port Pirie
# Processing Record 29 of Set 9 | lady frere
# OK
# Lady Frere
# OK
# Lady Frere
# Processing Record 30 of Set 9 | giddarbaha
# OK
# Giddarbaha
# OK
# Giddarbaha
# Processing Record 31 of Set 9 | podor
# OK
# Podor
# OK
# Podor
# Processing Record 32 of Set 9 | usinsk
# OK
# Usinsk
# OK
# Usinsk
# Processing Record 33 of Set 9 | berlevag
# OK
# Berlevag
# OK
# Berlevag
# Processing Record 34 of Set 9 | namibe
# OK
# Namibe
# OK
# Namibe
# Processing Record 35 of Set 9 | chifeng
# OK
# Chifeng
# OK
# Chifeng
# Processing Record 36 of Set 9 | camacha
# OK
# Camacha
# OK
# Camacha
# Processing Record 37 of Set 9 | san jose
# OK
# San Jose
# OK
# San Jose
# Processing Record 38 of Set 9 | evensk
# OK
# Evensk
# OK
# Evensk
# Processing Record 39 of Set 9 | benguela
# OK
# Benguela
# OK
# Benguela
# Processing Record 40 of Set 9 | kaeo
# OK
# Kaeo
# OK
# Kaeo
# Processing Record 41 of Set 9 | aklavik
# OK
# Aklavik
# OK
# Aklavik
# Processing Record 42 of Set 9 | rio grande
# OK
# Rio Grande
# OK
# Rio Grande
# Processing Record 43 of Set 9 | turner
# OK
# Turner
# OK
# Turner
# Processing Record 44 of Set 9 | awbari
# OK
# Awbari
# OK
# Awbari
# Processing Record 45 of Set 9 | santa maria da boa vista
# OK
# Santa Maria Da Boa Vista
# OK
# Santa Maria Da Boa Vista
# Processing Record 46 of Set 9 | eloy
# OK
# Eloy
# OK
# Eloy
# Processing Record 47 of Set 9 | rodrigues alves
# OK
# Rodrigues Alves
# OK
# Rodrigues Alves
# Processing Record 48 of Set 9 | zhigansk
# OK
# Zhigansk
# OK
# Zhigansk
# Processing Record 49 of Set 9 | manta
# OK
# Manta
# OK
# Manta
# Processing Record 50 of Set 9 | rota
# OK
# Rota
# OK
# Rota
# Processing Record 1 of Set 10 | mackay
# OK
# Mackay
# OK
# Mackay
# Processing Record 2 of Set 10 | fort nelson
# OK
# Fort Nelson
# OK
# Fort Nelson
# Processing Record 3 of Set 10 | nishihara
# OK
# Nishihara
# OK
# Nishihara
# Processing Record 4 of Set 10 | kilmez
# OK
# Kilmez
# OK
# Kilmez
# City not found. Skipping...
# Processing Record 5 of Set 10 | buckeye
# OK
# Buckeye
# OK
# Buckeye
# Processing Record 6 of Set 10 | bani walid
# OK
# Bani Walid
# OK
# Bani Walid
# Processing Record 7 of Set 10 | arauca
# OK
# Arauca
# OK
# Arauca
# Processing Record 8 of Set 10 | lasa
# OK
# Lasa
# OK
# Lasa
# Processing Record 9 of Set 10 | masakin
# OK
# Masakin
# OK
# Masakin
# Processing Record 10 of Set 10 | urdzhar
# OK
# Urdzhar
# OK
# Urdzhar
# City not found. Skipping...
# Processing Record 11 of Set 10 | hazorasp
# OK
# Hazorasp
# OK
# Hazorasp
# Processing Record 12 of Set 10 | mogadishu
# OK
# Mogadishu
# OK
# Mogadishu
# Processing Record 13 of Set 10 | krionerion
# OK
# Krionerion
# OK
# Krionerion
# City not found. Skipping...
# Processing Record 14 of Set 10 | krasnyy kut
# OK
# Krasnyy Kut
# OK
# Krasnyy Kut
# Processing Record 15 of Set 10 | maniitsoq
# OK
# Maniitsoq
# OK
# Maniitsoq
# Processing Record 16 of Set 10 | viransehir
# OK
# Viransehir
# OK
# Viransehir
# Processing Record 17 of Set 10 | ruteng
# OK
# Ruteng
# OK
# Ruteng
# Processing Record 18 of Set 10 | odoyev
# OK
# Odoyev
# OK
# Odoyev
# Processing Record 19 of Set 10 | sakakah
# OK
# Sakakah
# OK
# Sakakah
# Processing Record 20 of Set 10 | dingzhou
# OK
# Dingzhou
# OK
# Dingzhou
# Processing Record 21 of Set 10 | salinas
# OK
# Salinas
# OK
# Salinas
# Processing Record 22 of Set 10 | altdorf
# OK
# Altdorf
# OK
# Altdorf
# Processing Record 23 of Set 10 | bababe
# OK
# Bababe
# OK
# Bababe
# City not found. Skipping...
# Processing Record 24 of Set 10 | kahului
# OK
# Kahului
# OK
# Kahului
# Processing Record 25 of Set 10 | yefira
# OK
# Yefira
# OK
# Yefira
# City not found. Skipping...
# Processing Record 26 of Set 10 | cockburn harbour
# OK
# Cockburn Harbour
# OK
# Cockburn Harbour
# City not found. Skipping...
# Processing Record 27 of Set 10 | gurskoye
# OK
# Gurskoye
# OK
# Gurskoye
# City not found. Skipping...
# Processing Record 28 of Set 10 | kaeng khoi
# OK
# Kaeng Khoi
# OK
# Kaeng Khoi
# Processing Record 29 of Set 10 | mount gambier
# OK
# Mount Gambier
# OK
# Mount Gambier
# Processing Record 30 of Set 10 | lorengau
# OK
# Lorengau
# OK
# Lorengau
# Processing Record 31 of Set 10 | ixtapa
# OK
# Ixtapa
# OK
# Ixtapa
# Processing Record 32 of Set 10 | kumba
# OK
# Kumba
# OK
# Kumba
# Processing Record 33 of Set 10 | sheksna
# OK
# Sheksna
# OK
# Sheksna
# Processing Record 34 of Set 10 | manuk mangkaw
# OK
# Manuk Mangkaw
# OK
# Manuk Mangkaw
# Processing Record 35 of Set 10 | kapit
# OK
# Kapit
# OK
# Kapit
# Processing Record 36 of Set 10 | verkhnevilyuysk
# OK
# Verkhnevilyuysk
# OK
# Verkhnevilyuysk
# Processing Record 37 of Set 10 | san jeronimo
# OK
# San Jeronimo
# OK
# San Jeronimo
# Processing Record 38 of Set 10 | sidhi
# OK
# Sidhi
# OK
# Sidhi
# Processing Record 39 of Set 10 | bucerias
# OK
# Bucerias
# OK
# Bucerias
# Processing Record 40 of Set 10 | kuche
# OK
# Kuche
# OK
# Kuche
# City not found. Skipping...
# Processing Record 41 of Set 10 | hailar
# OK
# Hailar
# OK
# Hailar
# Processing Record 42 of Set 10 | abu kamal
# OK
# Abu Kamal
# OK
# Abu Kamal
# Processing Record 43 of Set 10 | yurginskoye
# OK
# Yurginskoye
# OK
# Yurginskoye
# Processing Record 44 of Set 10 | cap malheureux
# OK
# Cap Malheureux
# OK
# Cap Malheureux
# Processing Record 45 of Set 10 | uzunovo
# OK
# Uzunovo
# OK
# Uzunovo
# Processing Record 46 of Set 10 | pangody
# OK
# Pangody
# OK
# Pangody
# Processing Record 47 of Set 10 | iqaluit
# OK
# Iqaluit
# OK
# Iqaluit
# Processing Record 48 of Set 10 | tres arroyos
# OK
# Tres Arroyos
# OK
# Tres Arroyos
# Processing Record 49 of Set 10 | olindina
# OK
# Olindina
# OK
# Olindina
# Processing Record 50 of Set 10 | padang
# OK
# Padang
# OK
# Padang
# Processing Record 1 of Set 11 | crab hill
# OK
# Crab Hill
# OK
# Crab Hill
# City not found. Skipping...
# Processing Record 2 of Set 11 | kabompo
# OK
# Kabompo
# OK
# Kabompo
# Processing Record 3 of Set 11 | fort payne
# OK
# Fort Payne
# OK
# Fort Payne
# Processing Record 4 of Set 11 | murgab
# OK
# Murgab
# OK
# Murgab
# Processing Record 5 of Set 11 | soldotna
# OK
# Soldotna
# OK
# Soldotna
# Processing Record 6 of Set 11 | kavaratti
# OK
# Kavaratti
# OK
# Kavaratti
# Processing Record 7 of Set 11 | sambava
# OK
# Sambava
# OK
# Sambava
# Processing Record 8 of Set 11 | labuan
# OK
# Labuan
# OK
# Labuan
# Processing Record 9 of Set 11 | anloga
# OK
# Anloga
# OK
# Anloga
# Processing Record 10 of Set 11 | sahrak
# OK
# Sahrak
# OK
# Sahrak
# City not found. Skipping...
# Processing Record 11 of Set 11 | almeirim
# OK
# Almeirim
# OK
# Almeirim
# Processing Record 12 of Set 11 | cabedelo
# OK
# Cabedelo
# OK
# Cabedelo
# Processing Record 13 of Set 11 | fontanka
# OK
# Fontanka
# OK
# Fontanka
# Processing Record 14 of Set 11 | buala
# OK
# Buala
# OK
# Buala
# Processing Record 15 of Set 11 | liusha
# OK
# Liusha
# OK
# Liusha
# Processing Record 16 of Set 11 | kalmunai
# OK
# Kalmunai
# OK
# Kalmunai
# Processing Record 17 of Set 11 | juegang
# OK
# Juegang
# OK
# Juegang
# Processing Record 18 of Set 11 | bosanski samac
# OK
# Bosanski Samac
# OK
# Bosanski Samac
# Processing Record 19 of Set 11 | krasnyy luch
# OK
# Krasnyy Luch
# OK
# Krasnyy Luch
# Processing Record 20 of Set 11 | gorno-chuyskiy
# OK
# Gorno-Chuyskiy
# OK
# Gorno-Chuyskiy
# City not found. Skipping...
# Processing Record 21 of Set 11 | fairbanks
# OK
# Fairbanks
# OK
# Fairbanks
# Processing Record 22 of Set 11 | nioro
# OK
# Nioro
# OK
# Nioro
# Processing Record 23 of Set 11 | cukai
# OK
# Cukai
# OK
# Cukai
# Processing Record 24 of Set 11 | shenjiamen
# OK
# Shenjiamen
# OK
# Shenjiamen
# Processing Record 25 of Set 11 | oriximina
# OK
# Oriximina
# OK
# Oriximina
# Processing Record 26 of Set 11 | bonavista
# OK
# Bonavista
# OK
# Bonavista
# Processing Record 27 of Set 11 | bogorodskoye
# OK
# Bogorodskoye
# OK
# Bogorodskoye
# Processing Record 28 of Set 11 | yulara
# OK
# Yulara
# OK
# Yulara
# Processing Record 29 of Set 11 | bama
# OK
# Bama
# OK
# Bama
# Processing Record 30 of Set 11 | nanakuli
# OK
# Nanakuli
# OK
# Nanakuli
# Processing Record 31 of Set 11 | wamba
# OK
# Wamba
# OK
# Wamba
# Processing Record 32 of Set 11 | maridi
# OK
# Maridi
# OK
# Maridi
# Processing Record 33 of Set 11 | katobu
# OK
# Katobu
# OK
# Katobu
# Processing Record 34 of Set 11 | sibolga
# OK
# Sibolga
# OK
# Sibolga
# Processing Record 35 of Set 11 | ontario
# OK
# Ontario
# OK
# Ontario
# Processing Record 36 of Set 11 | cikarang
# OK
# Cikarang
# OK
# Cikarang
# Processing Record 37 of Set 11 | lagos
# OK
# Lagos
# OK
# Lagos
# Processing Record 38 of Set 11 | zyryanka
# OK
# Zyryanka
# OK
# Zyryanka
# Processing Record 39 of Set 11 | biograd na moru
# OK
# Biograd Na Moru
# OK
# Biograd Na Moru
# Processing Record 40 of Set 11 | qingan
# OK
# Qingan
# OK
# Qingan
# City not found. Skipping...
# Processing Record 41 of Set 11 | hamilton
# OK
# Hamilton
# OK
# Hamilton
# Processing Record 42 of Set 11 | derzhavinsk
# OK
# Derzhavinsk
# OK
# Derzhavinsk
# Processing Record 43 of Set 11 | campbellton
# OK
# Campbellton
# OK
# Campbellton
# Processing Record 44 of Set 11 | saquena
# OK
# Saquena
# OK
# Saquena
# Processing Record 45 of Set 11 | angoche
# OK
# Angoche
# OK
# Angoche
# Processing Record 46 of Set 11 | katoro
# OK
# Katoro
# OK
# Katoro
# Processing Record 47 of Set 11 | nouadhibou
# OK
# Nouadhibou
# OK
# Nouadhibou
# Processing Record 48 of Set 11 | gladstone
# OK
# Gladstone
# OK
# Gladstone
# Processing Record 49 of Set 11 | manzil jamil
# OK
# Manzil Jamil
# OK
# Manzil Jamil
# City not found. Skipping...
# Processing Record 50 of Set 11 | key west
# OK
# Key West
# OK
# Key West
# Processing Record 1 of Set 12 | powell river
# OK
# Powell River
# OK
# Powell River
# Processing Record 2 of Set 12 | hohhot
# OK
# Hohhot
# OK
# Hohhot
# Processing Record 3 of Set 12 | chapais
# OK
# Chapais
# OK
# Chapais
# Processing Record 4 of Set 12 | bilma
# OK
# Bilma
# OK
# Bilma
# Processing Record 5 of Set 12 | manokwari
# OK
# Manokwari
# OK
# Manokwari
# Processing Record 6 of Set 12 | sistranda
# OK
# Sistranda
# OK
# Sistranda
# Processing Record 7 of Set 12 | lima
# OK
# Lima
# OK
# Lima
# Processing Record 8 of Set 12 | davila
# OK
# Davila
# OK
# Davila
# Processing Record 9 of Set 12 | meulaboh
# OK
# Meulaboh
# OK
# Meulaboh
# Processing Record 10 of Set 12 | kharovsk
# OK
# Kharovsk
# OK
# Kharovsk
# Processing Record 11 of Set 12 | dawlatabad
# OK
# Dawlatabad
# OK
# Dawlatabad
# Processing Record 12 of Set 12 | shitanjing
# OK
# Shitanjing
# OK
# Shitanjing
# Processing Record 13 of Set 12 | mizdah
# OK
# Mizdah
# OK
# Mizdah
# Processing Record 14 of Set 12 | stepnyak
# OK
# Stepnyak
# OK
# Stepnyak
# Processing Record 15 of Set 12 | puerto carreno
# OK
# Puerto Carreno
# OK
# Puerto Carreno
# Processing Record 16 of Set 12 | tornio
# OK
# Tornio
# OK
# Tornio
# Processing Record 17 of Set 12 | mandurah
# OK
# Mandurah
# OK
# Mandurah
# Processing Record 18 of Set 12 | kloulklubed
# OK
# Kloulklubed
# OK
# Kloulklubed
# Processing Record 19 of Set 12 | bodden town
# OK
# Bodden Town
# OK
# Bodden Town
# Processing Record 20 of Set 12 | bonthe
# OK
# Bonthe
# OK
# Bonthe
# Processing Record 21 of Set 12 | antsohihy
# OK
# Antsohihy
# OK
# Antsohihy
# Processing Record 22 of Set 12 | chernyshevskiy
# OK
# Chernyshevskiy
# OK
# Chernyshevskiy
# Processing Record 23 of Set 12 | axim
# OK
# Axim
# OK
# Axim
# Processing Record 24 of Set 12 | divnomorskoye
# OK
# Divnomorskoye
# OK
# Divnomorskoye
# Processing Record 25 of Set 12 | sawakin
# OK
# Sawakin
# OK
# Sawakin
# Processing Record 26 of Set 12 | ratnagiri
# OK
# Ratnagiri
# OK
# Ratnagiri
# Processing Record 27 of Set 12 | saint anthony
# OK
# Saint Anthony
# OK
# Saint Anthony
# Processing Record 28 of Set 12 | zaragoza
# OK
# Zaragoza
# OK
# Zaragoza
# Processing Record 29 of Set 12 | rudbar
# OK
# Rudbar
# OK
# Rudbar
# Processing Record 30 of Set 12 | renfrew
# OK
# Renfrew
# OK
# Renfrew
# Processing Record 31 of Set 12 | petrolandia
# OK
# Petrolandia
# OK
# Petrolandia
# City not found. Skipping...
# Processing Record 32 of Set 12 | yeppoon
# OK
# Yeppoon
# OK
# Yeppoon
# Processing Record 33 of Set 12 | komsomolskiy
# OK
# Komsomolskiy
# OK
# Komsomolskiy
# Processing Record 34 of Set 12 | pandan
# OK
# Pandan
# OK
# Pandan
# Processing Record 35 of Set 12 | namatanai
# OK
# Namatanai
# OK
# Namatanai
# Processing Record 36 of Set 12 | asyut
# OK
# Asyut
# OK
# Asyut
# Processing Record 37 of Set 12 | dobreni
# OK
# Dobreni
# OK
# Dobreni
# Processing Record 38 of Set 12 | carauari
# OK
# Carauari
# OK
# Carauari
# Processing Record 39 of Set 12 | atherton
# OK
# Atherton
# OK
# Atherton
# Processing Record 40 of Set 12 | conakry
# OK
# Conakry
# OK
# Conakry
# Processing Record 41 of Set 12 | adrar
# OK
# Adrar
# OK
# Adrar
# Processing Record 42 of Set 12 | mezen
# OK
# Mezen
# OK
# Mezen
# Processing Record 43 of Set 12 | north bend
# OK
# North Bend
# OK
# North Bend
# Processing Record 44 of Set 12 | nautla
# OK
# Nautla
# OK
# Nautla
# Processing Record 45 of Set 12 | gat
# OK
# Gat
# OK
# Gat
# Processing Record 46 of Set 12 | sobolevo
# OK
# Sobolevo
# OK
# Sobolevo
# Processing Record 47 of Set 12 | kirkland lake
# OK
# Kirkland Lake
# OK
# Kirkland Lake
# Processing Record 48 of Set 12 | neepawa
# OK
# Neepawa
# OK
# Neepawa
# Processing Record 49 of Set 12 | abnub
# OK
# Abnub
# OK
# Abnub
# Processing Record 50 of Set 12 | barsovo
# OK
# Barsovo
# OK
# Barsovo
# Processing Record 1 of Set 13 | uwayl
# OK
# Uwayl
# OK
# Uwayl
# City not found. Skipping...
# Processing Record 2 of Set 13 | sentyabrskiy
# OK
# Sentyabrskiy
# OK
# Sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 13 | kirakira
# OK
# Kirakira
# OK
# Kirakira
# Processing Record 4 of Set 13 | fare
# OK
# Fare
# OK
# Fare
# Processing Record 5 of Set 13 | rushden
# OK
# Rushden
# OK
# Rushden
# Processing Record 6 of Set 13 | jackson
# OK
# Jackson
# OK
# Jackson
# Processing Record 7 of Set 13 | banikoara
# OK
# Banikoara
# OK
# Banikoara
# Processing Record 8 of Set 13 | vila franca do campo
# OK
# Vila Franca Do Campo
# OK
# Vila Franca Do Campo
# Processing Record 9 of Set 13 | bria
# OK
# Bria
# OK
# Bria
# Processing Record 10 of Set 13 | sembe
# OK
# Sembe
# OK
# Sembe
# Processing Record 11 of Set 13 | banmo
# OK
# Banmo
# OK
# Banmo
# City not found. Skipping...
# Processing Record 12 of Set 13 | suntar
# OK
# Suntar
# OK
# Suntar
# Processing Record 13 of Set 13 | khandyga
# OK
# Khandyga
# OK
# Khandyga
# Processing Record 14 of Set 13 | vila velha
# OK
# Vila Velha
# OK
# Vila Velha
# Processing Record 15 of Set 13 | nikolayevsk-na-amure
# OK
# Nikolayevsk-Na-Amure
# OK
# Nikolayevsk-Na-Amure
# Processing Record 16 of Set 13 | ahuimanu
# OK
# Ahuimanu
# OK
# Ahuimanu
# Processing Record 17 of Set 13 | bilibino
# OK
# Bilibino
# OK
# Bilibino
# Processing Record 18 of Set 13 | ayugan
# OK
# Ayugan
# OK
# Ayugan
# Processing Record 19 of Set 13 | tumannyy
# OK
# Tumannyy
# OK
# Tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 13 | nara
# OK
# Nara
# OK
# Nara
# Processing Record 21 of Set 13 | necochea
# OK
# Necochea
# OK
# Necochea
# Processing Record 22 of Set 13 | alpena
# OK
# Alpena
# OK
# Alpena
# Processing Record 23 of Set 13 | bairiki
# OK
# Bairiki
# OK
# Bairiki
# Processing Record 24 of Set 13 | dzilam gonzalez
# OK
# Dzilam Gonzalez
# OK
# Dzilam Gonzalez
# Processing Record 25 of Set 13 | laguna
# OK
# Laguna
# OK
# Laguna
# Processing Record 26 of Set 13 | tiarei
# OK
# Tiarei
# OK
# Tiarei
# Processing Record 27 of Set 13 | patacamaya
# OK
# Patacamaya
# OK
# Patacamaya
# Processing Record 28 of Set 13 | qui nhon
# OK
# Qui Nhon
# OK
# Qui Nhon
# Processing Record 29 of Set 13 | grand river south east
# OK
# Grand River South East
# OK
# Grand River South East
# City not found. Skipping...
# Processing Record 30 of Set 13 | callaway
# OK
# Callaway
# OK
# Callaway
# Processing Record 31 of Set 13 | palora
# OK
# Palora
# OK
# Palora
# Processing Record 32 of Set 13 | rameshki
# OK
# Rameshki
# OK
# Rameshki
# Processing Record 33 of Set 13 | siyabuswa
# OK
# Siyabuswa
# OK
# Siyabuswa
# Processing Record 34 of Set 13 | maceio
# OK
# Maceio
# OK
# Maceio
# Processing Record 35 of Set 13 | bara
# OK
# Bara
# OK
# Bara
# Processing Record 36 of Set 13 | chagda
# OK
# Chagda
# OK
# Chagda
# City not found. Skipping...
# Processing Record 37 of Set 13 | ilhabela
# OK
# Ilhabela
# OK
# Ilhabela
# Processing Record 38 of Set 13 | zunheboto
# OK
# Zunheboto
# OK
# Zunheboto
# Processing Record 39 of Set 13 | creston
# OK
# Creston
# OK
# Creston
# Processing Record 40 of Set 13 | ambilobe
# OK
# Ambilobe
# OK
# Ambilobe
# Processing Record 41 of Set 13 | dongsheng
# OK
# Dongsheng
# OK
# Dongsheng
# Processing Record 42 of Set 13 | kodinsk
# OK
# Kodinsk
# OK
# Kodinsk
# Processing Record 43 of Set 13 | bay city
# OK
# Bay City
# OK
# Bay City
# Processing Record 44 of Set 13 | alugan
# OK
# Alugan
# OK
# Alugan
# Processing Record 45 of Set 13 | warmbad
# OK
# Warmbad
# OK
# Warmbad
# Processing Record 46 of Set 13 | san luis
# OK
# San Luis
# OK
# San Luis
# Processing Record 47 of Set 13 | ikryanoye
# OK
# Ikryanoye
# OK
# Ikryanoye
# Processing Record 48 of Set 13 | mackenzie
# OK
# Mackenzie
# OK
# Mackenzie
# Processing Record 49 of Set 13 | dumas
# OK
# Dumas
# OK
# Dumas
# Processing Record 50 of Set 13 | vanimo
# OK
# Vanimo
# OK
# Vanimo
# Processing Record 1 of Set 14 | mirnyy
# OK
# Mirnyy
# OK
# Mirnyy
# Processing Record 2 of Set 14 | khor
# OK
# Khor
# OK
# Khor
# Processing Record 3 of Set 14 | aksu
# OK
# Aksu
# OK
# Aksu
# Processing Record 4 of Set 14 | frolovo
# OK
# Frolovo
# OK
# Frolovo
# Processing Record 5 of Set 14 | najran
# OK
# Najran
# OK
# Najran
# Processing Record 6 of Set 14 | altamira
# OK
# Altamira
# OK
# Altamira
# Processing Record 7 of Set 14 | taoudenni
# OK
# Taoudenni
# OK
# Taoudenni
# Processing Record 8 of Set 14 | paola
# OK
# Paola
# OK
# Paola
# Processing Record 9 of Set 14 | cockburn town
# OK
# Cockburn Town
# OK
# Cockburn Town
# Processing Record 10 of Set 14 | touros
# OK
# Touros
# OK
# Touros
# Processing Record 11 of Set 14 | port macquarie
# OK
# Port Macquarie
# OK
# Port Macquarie
# Processing Record 12 of Set 14 | verkhnyaya sinyachikha
# OK
# Verkhnyaya Sinyachikha
# OK
# Verkhnyaya Sinyachikha
# Processing Record 13 of Set 14 | langsa
# OK
# Langsa
# OK
# Langsa
# Processing Record 14 of Set 14 | helena
# OK
# Helena
# OK
# Helena
# Processing Record 15 of Set 14 | bisauli
# OK
# Bisauli
# OK
# Bisauli
# Processing Record 16 of Set 14 | comodoro rivadavia
# OK
# Comodoro Rivadavia
# OK
# Comodoro Rivadavia
# Processing Record 17 of Set 14 | aripuana
# OK
# Aripuana
# OK
# Aripuana
# Processing Record 18 of Set 14 | halalo
# OK
# Halalo
# OK
# Halalo
# City not found. Skipping...
# Processing Record 19 of Set 14 | cardston
# OK
# Cardston
# OK
# Cardston
# Processing Record 20 of Set 14 | uyuni
# OK
# Uyuni
# OK
# Uyuni
# Processing Record 21 of Set 14 | botou
# OK
# Botou
# OK
# Botou
# Processing Record 22 of Set 14 | clemson
# OK
# Clemson
# OK
# Clemson
# Processing Record 23 of Set 14 | sabang
# OK
# Sabang
# OK
# Sabang
# Processing Record 24 of Set 14 | kimbe
# OK
# Kimbe
# OK
# Kimbe
# Processing Record 25 of Set 14 | orange park
# OK
# Orange Park
# OK
# Orange Park
# Processing Record 26 of Set 14 | paita
# OK
# Paita
# OK
# Paita
# Processing Record 27 of Set 14 | plastun
# OK
# Plastun
# OK
# Plastun
# Processing Record 28 of Set 14 | goderich
# OK
# Goderich
# OK
# Goderich
# Processing Record 29 of Set 14 | marawi
# OK
# Marawi
# OK
# Marawi
# Processing Record 30 of Set 14 | ilinskiy
# OK
# Ilinskiy
# OK
# Ilinskiy
# Processing Record 31 of Set 14 | bordighera
# OK
# Bordighera
# OK
# Bordighera
# Processing Record 32 of Set 14 | solsvik
# OK
# Solsvik
# OK
# Solsvik
# City not found. Skipping...
# Processing Record 33 of Set 14 | rio brilhante
# OK
# Rio Brilhante
# OK
# Rio Brilhante
# Processing Record 34 of Set 14 | sinop
# OK
# Sinop
# OK
# Sinop
# Processing Record 35 of Set 14 | san quintin
# OK
# San Quintin
# OK
# San Quintin
# Processing Record 36 of Set 14 | maraial
# OK
# Maraial
# OK
# Maraial
# Processing Record 37 of Set 14 | dentsville
# OK
# Dentsville
# OK
# Dentsville
# Processing Record 38 of Set 14 | poum
# OK
# Poum
# OK
# Poum
# Processing Record 39 of Set 14 | hihifo
# OK
# Hihifo
# OK
# Hihifo
# City not found. Skipping...
# Processing Record 40 of Set 14 | yangambi
# OK
# Yangambi
# OK
# Yangambi
# Processing Record 41 of Set 14 | redlands
# OK
# Redlands
# OK
# Redlands
# Processing Record 42 of Set 14 | okhotsk
# OK
# Okhotsk
# OK
# Okhotsk
# Processing Record 43 of Set 14 | boat of garten
# OK
# Boat Of Garten
# OK
# Boat Of Garten
# Processing Record 44 of Set 14 | sao felix do xingu
# OK
# Sao Felix Do Xingu
# OK
# Sao Felix Do Xingu
# Processing Record 45 of Set 14 | hinatuan
# OK
# Hinatuan
# OK
# Hinatuan
# Processing Record 46 of Set 14 | flinders
# OK
# Flinders
# OK
# Flinders
# Processing Record 47 of Set 14 | klyuchi
# OK
# Klyuchi
# OK
# Klyuchi
# Processing Record 48 of Set 14 | san pedro
# OK
# San Pedro
# OK
# San Pedro
# Processing Record 49 of Set 14 | acapulco
# OK
# Acapulco
# OK
# Acapulco
# Processing Record 50 of Set 14 | nalut
# OK
# Nalut
# OK
# Nalut
# Processing Record 1 of Set 15 | wajima
# OK
# Wajima
# OK
# Wajima
# Processing Record 2 of Set 15 | igarka
# OK
# Igarka
# OK
# Igarka
# Processing Record 3 of Set 15 | sukumo
# OK
# Sukumo
# OK
# Sukumo
# Processing Record 4 of Set 15 | enid
# OK
# Enid
# OK
# Enid
# Processing Record 5 of Set 15 | awjilah
# OK
# Awjilah
# OK
# Awjilah
# Processing Record 6 of Set 15 | sorland
# OK
# Sorland
# OK
# Sorland
# Processing Record 7 of Set 15 | ancud
# OK
# Ancud
# OK
# Ancud
# Processing Record 8 of Set 15 | sitka
# OK
# Sitka
# OK
# Sitka
# Processing Record 9 of Set 15 | cartagena
# OK
# Cartagena
# OK
# Cartagena
# Processing Record 10 of Set 15 | san carlos de bariloche
# OK
# San Carlos De Bariloche
# OK
# San Carlos De Bariloche
# Processing Record 11 of Set 15 | buqayq
# OK
# Buqayq
# OK
# Buqayq
# City not found. Skipping...
# Processing Record 12 of Set 15 | shimoda
# OK
# Shimoda
# OK
# Shimoda
# Processing Record 13 of Set 15 | galle
# OK
# Galle
# OK
# Galle
# Processing Record 14 of Set 15 | fayaoue
# OK
# Fayaoue
# OK
# Fayaoue
# Processing Record 15 of Set 15 | akdepe
# OK
# Akdepe
# OK
# Akdepe
# Processing Record 16 of Set 15 | kutum
# OK
# Kutum
# OK
# Kutum
# Processing Record 17 of Set 15 | teknaf
# OK
# Teknaf
# OK
# Teknaf
# Processing Record 18 of Set 15 | elk city
# OK
# Elk City
# OK
# Elk City
# Processing Record 19 of Set 15 | sioux lookout
# OK
# Sioux Lookout
# OK
# Sioux Lookout
# Processing Record 20 of Set 15 | satka
# OK
# Satka
# OK
# Satka
# Processing Record 21 of Set 15 | ventspils
# OK
# Ventspils
# OK
# Ventspils
# Processing Record 22 of Set 15 | marsh harbour
# OK
# Marsh Harbour
# OK
# Marsh Harbour
# Processing Record 23 of Set 15 | eureka
# OK
# Eureka
# OK
# Eureka
# Processing Record 24 of Set 15 | zamora
# OK
# Zamora
# OK
# Zamora
# Processing Record 25 of Set 15 | okha
# OK
# Okha
# OK
# Okha
# Processing Record 26 of Set 15 | west bend
# OK
# West Bend
# OK
# West Bend
# Processing Record 27 of Set 15 | burnie
# OK
# Burnie
# OK
# Burnie
# Processing Record 28 of Set 15 | osoyoos
# OK
# Osoyoos
# OK
# Osoyoos
# Processing Record 29 of Set 15 | santa maria
# OK
# Santa Maria
# OK
# Santa Maria
# Processing Record 30 of Set 15 | lompoc
# OK
# Lompoc
# OK
# Lompoc
# Processing Record 31 of Set 15 | tyukalinsk
# OK
# Tyukalinsk
# OK
# Tyukalinsk
# Processing Record 32 of Set 15 | mobaye
# OK
# Mobaye
# OK
# Mobaye
# Processing Record 33 of Set 15 | quatre cocos
# OK
# Quatre Cocos
# OK
# Quatre Cocos
# Processing Record 34 of Set 15 | toliary
# OK
# Toliary
# OK
# Toliary
# City not found. Skipping...
# Processing Record 35 of Set 15 | wajir
# OK
# Wajir
# OK
# Wajir
# Processing Record 36 of Set 15 | melekhovo
# OK
# Melekhovo
# OK
# Melekhovo
# Processing Record 37 of Set 15 | abu zabad
# OK
# Abu Zabad
# OK
# Abu Zabad
# Processing Record 38 of Set 15 | buraydah
# OK
# Buraydah
# OK
# Buraydah
# Processing Record 39 of Set 15 | pangnirtung
# OK
# Pangnirtung
# OK
# Pangnirtung
# Processing Record 40 of Set 15 | karatau
# OK
# Karatau
# OK
# Karatau
# Processing Record 41 of Set 15 | north battleford
# OK
# North Battleford
# OK
# North Battleford
# Processing Record 42 of Set 15 | esmeralda
# OK
# Esmeralda
# OK
# Esmeralda
# Processing Record 43 of Set 15 | sajanan
# OK
# Sajanan
# OK
# Sajanan
# Processing Record 44 of Set 15 | lata
# OK
# Lata
# OK
# Lata
# Processing Record 45 of Set 15 | aksha
# OK
# Aksha
# OK
# Aksha
# Processing Record 46 of Set 15 | gorontalo
# OK
# Gorontalo
# OK
# Gorontalo
# Processing Record 47 of Set 15 | esqueda
# OK
# Esqueda
# OK
# Esqueda
# Processing Record 48 of Set 15 | beisfjord
# OK
# Beisfjord
# OK
# Beisfjord
# Processing Record 49 of Set 15 | walvis bay
# OK
# Walvis Bay
# OK
# Walvis Bay
# Processing Record 50 of Set 15 | mocuba
# OK
# Mocuba
# OK
# Mocuba
# Processing Record 1 of Set 16 | kuchera
# OK
# Kuchera
# OK
# Kuchera
# Processing Record 2 of Set 16 | siniscola
# OK
# Siniscola
# OK
# Siniscola
# Processing Record 3 of Set 16 | barra do garcas
# OK
# Barra Do Garcas
# OK
# Barra Do Garcas
# Processing Record 4 of Set 16 | quba
# OK
# Quba
# OK
# Quba
# Processing Record 5 of Set 16 | darhan
# OK
# Darhan
# OK
# Darhan
# Processing Record 6 of Set 16 | panjab
# OK
# Panjab
# OK
# Panjab
# Processing Record 7 of Set 16 | morant bay
# OK
# Morant Bay
# OK
# Morant Bay
# Processing Record 8 of Set 16 | petropavlovsk-kamchatskiy
# OK
# Petropavlovsk-Kamchatskiy
# OK
# Petropavlovsk-Kamchatskiy
# Processing Record 9 of Set 16 | luwuk
# OK
# Luwuk
# OK
# Luwuk
# Processing Record 10 of Set 16 | yanji
# OK
# Yanji
# OK
# Yanji
# Processing Record 11 of Set 16 | ngawi
# OK
# Ngawi
# OK
# Ngawi
# Processing Record 12 of Set 16 | maxixe
# OK
# Maxixe
# OK
# Maxixe
# Processing Record 13 of Set 16 | monterey
# OK
# Monterey
# OK
# Monterey
# Processing Record 14 of Set 16 | malayal
# OK
# Malayal
# OK
# Malayal
# Processing Record 15 of Set 16 | englehart
# OK
# Englehart
# OK
# Englehart
# Processing Record 16 of Set 16 | qasigiannguit
# OK
# Qasigiannguit
# OK
# Qasigiannguit
# Processing Record 17 of Set 16 | puerto leguizamo
# OK
# Puerto Leguizamo
# OK
# Puerto Leguizamo
# Processing Record 18 of Set 16 | ketchikan
# OK
# Ketchikan
# OK
# Ketchikan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 667

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hermanus      ZA -34.4187   19.2345     73.80        73          79
# 1          Castro      BR -24.7911  -50.0119     63.28        90          95
# 2           Yatou      CN  37.1500  122.3833     43.32        61          18
# 3     Kapuskasing      CA  49.4169  -82.4331     21.20        86         100
# 4          Juneau      US  58.3019 -134.4197     36.10        97         100
# 5      Mugur-Aksy      RU  50.3500   90.5000     12.72        90         100
# 6  Cabo San Lucas      MX  22.8909 -109.9124     67.51        69           9
# 7         Talnakh      RU  69.4865   88.3972     -2.97        98         100
# 8      Bredasdorp      ZA -34.5322   20.0403     71.58        78          77
# 9      Palmerston      AU -12.4860  130.9833     85.89        79          75
#
#    Wind Speed      Current Description
# 0       15.57            broken clouds
# 1        5.53          overcast clouds
# 2        6.82               few clouds
# 3       11.50                     snow
# 4        3.44  light intensity drizzle
# 5        4.43               light snow
# 6        3.33                clear sky
# 7       15.48               light snow
# 8       13.78            broken clouds
# 9       10.36            broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Lat", "Lng", "Max Temp", "Current Description", "Humidity",  "Cloudiness", "Wind Speed", "Country"
print("Columns already in order")

# Display sample data
city_data_df.head()
# Out:
# Columns already in order
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hermanus      ZA -34.4187   19.2345     73.80        73          79
# 1       Castro      BR -24.7911  -50.0119     63.28        90          95
# 2        Yatou      CN  37.1500  122.3833     43.32        61          18
# 3  Kapuskasing      CA  49.4169  -82.4331     21.20        86         100
# 4       Juneau      US  58.3019 -134.4197     36.10        97         100
#
#    Wind Speed      Current Description
# 0       15.57            broken clouds
# 1        5.53          overcast clouds
# 2        6.82               few clouds
# 3       11.50                     snow
# 4        3.44  light intensity drizzle

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
